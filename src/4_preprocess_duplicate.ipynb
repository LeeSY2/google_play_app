# %%
import pandas as pd
import numpy as npa
from const import KB,MB,GB
from lib import check_libs_installed, get_processing_folder_path

# %%
df = pd.read_csv(get_processing_folder_path('processed_temp.csv'))

# %%
target = df[['App Name','Rating Count']].sort_values(by=['App Name','Rating Count'],ascending=False)
target = target.loc[target.duplicated(subset=['App Name'],keep=False)]
target = target.loc[~target.duplicated(subset=['App Name'],keep='last')].index.tolist()
target
# Out:
# [1633038,
#  214338,
#  1331504,
#  1792522,
#  1475657,
#  1292685,
#  424857,
#  2143755,
#  1934918,
#  1022043,
#  1092058,
#  1284471,
#  2125347,
#  592617,
#  1801468,
#  664331,
#  953761,
#  815595,
#  1776254,
#  1815000,
#  480004,
#  378289,
#  1146842,
#  1798164,
#  1456549,
#  2251657,
#  586497,
#  26944,
#  364183,
#  1852066,
#  2035633,
#  462305,
#  1644298,
#  1583741,
#  1860555,
#  402479,
#  2263696,
#  753162,
#  1401552,
#  1742521,
#  199449,
#  2132572,
#  1364337,
#  1825372,
#  1461524,
#  1739106,
#  1775227,
#  2109861,
#  289204,
#  937504,
#  1774264,
#  1192357,
#  807564,
#  1851977,
#  1886582,
#  2247839,
#  1691659,
#  1617641,
#  2087310,
#  704179,
#  2044262,
#  847472,
#  175911,
#  2060778,
#  1559631,
#  1462490,
#  645696,
#  1128961,
#  993589,
#  1821102,
#  1393158,
#  1759902,
#  1791376,
#  2117026,
#  543192,
#  512415,
#  1703476,
#  300561,
#  812119,
#  812324,
#  714638,
#  1051538,
#  1003286,
#  1617674,
#  2282410,
#  1162035,
#  1108381,
#  1143244,
#  2184799,
#  1112154,
#  208599,
#  1176910,
#  1800988,
#  786250,
#  1267711,
#  1105494,
#  1816308,
#  1322629,
#  1295238,
#  1393219,
#  1394151,
#  1906218,
#  1611379,
#  1783552,
#  1994036,
#  1273260,
#  1797766,
#  1315869,
#  2035690,
#  999646,
#  1212803,
#  246837,
#  2258811,
#  1716911,
#  809447,
#  6637,
#  1809067,
#  522045,
#  2028515,
#  1043315,
#  1168881,
#  2027952,
#  1541345,
#  577379,
#  1717215,
#  295350,
#  1185518,
#  1434314,
#  969105,
#  862080,
#  1536345,
#  2073367,
#  1471427,
#  169581,
#  1959251,
#  1211912,
#  2238304,
#  364458,
#  377831,
#  233523,
#  1412146,
#  1428332,
#  1284073,
#  1476731,
#  181094,
#  2045876,
#  1295395,
#  1939052,
#  1172572,
#  2254636,
#  707538,
#  2054654,
#  73700,
#  386640,
#  1579581,
#  1434888,
#  1537870,
#  553499,
#  1620746,
#  2029198,
#  1300002,
#  921776,
#  522998,
#  2047165,
#  413925,
#  2111991,
#  802257,
#  337125,
#  1997348,
#  1353955,
#  1520668,
#  2137926,
#  1747907,
#  341347,
#  2255826,
#  1106069,
#  1982408,
#  1955011,
#  415987,
#  2199419,
#  2021484,
#  850344,
#  601866,
#  834585,
#  779896,
#  942898,
#  19643,
#  218536,
#  1895761,
#  1050496,
#  1061852,
#  1445770,
#  719106,
#  1577614,
#  261098,
#  343043,
#  1911512,
#  1573289,
#  1475419,
#  1705035,
#  822698,
#  180767,
#  1030390,
#  2275889,
#  1605180,
#  1162833,
#  1606556,
#  1201303,
#  2046956,
#  84400,
#  467400,
#  1832768,
#  1553088,
#  1041869,
#  1353076,
#  1705482,
#  1463795,
#  1676364,
#  999871,
#  1582956,
#  830987,
#  2218386,
#  1307274,
#  1555432,
#  1866520,
#  1785864,
#  1985319,
#  382114,
#  572305,
#  1954736,
#  1697237,
#  1445231,
#  1825251,
#  519390,
#  2205802,
#  1876348,
#  566075,
#  183563,
#  763143,
#  1763124,
#  1491002,
#  1726351,
#  832957,
#  2190765,
#  2242833,
#  678199,
#  25149,
#  1998393,
#  1901459,
#  565489,
#  1541126,
#  1408466,
#  1852654,
#  1417097,
#  2054197,
#  2147332,
#  970591,
#  75826,
#  981827,
#  1748551,
#  1199997,
#  1077262,
#  2183712,
#  1512840,
#  47834,
#  909740,
#  1144373,
#  1187504,
#  997255,
#  421507,
#  1139850,
#  2093600,
#  366285,
#  1607813,
#  336463,
#  1910423,
#  2169932,
#  1429412,
#  112061,
#  503138,
#  2159487,
#  331425,
#  1236478,
#  878264,
#  1473385,
#  1496699,
#  1284942,
#  1461687,
#  2098101,
#  1118958,
#  1581324,
#  145180,
#  1120126,
#  1351981,
#  1961632,
#  2176589,
#  1607417,
#  854117,
#  2142607,
#  80742,
#  1471569,
#  954482,
#  1063571,
#  997321,
#  1139721,
#  1171837,
#  1378238,
#  1029708,
#  2031130,
#  1357410,
#  964678,
#  1541682,
#  631055,
#  1177571,
#  1125119,
#  1100657,
#  2261389,
#  750183,
#  1587655,
#  742755,
#  32083,
#  1892835,
#  2051423,
#  676301,
#  2183541,
#  851935,
#  1785692,
#  181914,
#  491158,
#  102638,
#  1495064,
#  164685,
#  1089817,
#  1319974,
#  2045527,
#  1313011,
#  1689578,
#  227697,
#  191518,
#  690585,
#  2147728,
#  1408848,
#  388977,
#  1379704,
#  524672,
#  1739163,
#  1313017,
#  671780,
#  2088783,
#  1439314,
#  1112874,
#  287437,
#  541312,
#  1783509,
#  1064078,
#  1767433,
#  493669,
#  2226474,
#  1502886,
#  1000732,
#  1586081,
#  1441206,
#  1519894,
#  1251087,
#  119724,
#  578562,
#  570317,
#  1483878,
#  818683,
#  517759,
#  1533119,
#  1009247,
#  2131519,
#  1406759,
#  442775,
#  1680893,
#  609623,
#  1969653,
#  248944,
#  2037691,
#  1995017,
#  1548470,
#  69229,
#  1959166,
#  2047629,
#  1471817,
#  1807311,
#  2152331,
#  2079291,
#  2092547,
#  1045682,
#  496956,
#  1528071,
#  356629,
#  491982,
#  2143467,
#  1068290,
#  1597508,
#  820697,
#  1548671,
#  1510989,
#  1297504,
#  1728184,
#  1167812,
#  985280,
#  810253,
#  878638,
#  1240065,
#  1580686,
#  1329638,
#  1587149,
#  1368702,
#  608693,
#  600934,
#  645837,
#  987833,
#  1130054,
#  1816592,
#  937651,
#  2284764,
#  1957475,
#  161477,
#  2115344,
#  1367604,
#  2163809,
#  34981,
#  1583618,
#  1207328,
#  2139304,
#  522473,
#  1473499,
#  2216763,
#  2217552,
#  540606,
#  428738,
#  542727,
#  1952104,
#  958154,
#  39400,
#  550845,
#  2011181,
#  959979,
#  1275832,
#  1759716,
#  1827632,
#  947762,
#  599147,
#  797226,
#  104362,
#  2124377,
#  1845037,
#  1761038,
#  779393,
#  105981,
#  1565308,
#  1788281,
#  1090467,
#  1632318,
#  1912598,
#  122505,
#  1834659,
#  1313285,
#  2218592,
#  1826757,
#  1555605,
#  2238216,
#  447867,
#  2228931,
#  2163751,
#  54566,
#  90041,
#  736568,
#  1224726,
#  1040187,
#  781006,
#  2286753,
#  1358112,
#  1085069,
#  1665044,
#  1279311,
#  2078279,
#  1091127,
#  1651412,
#  1273541,
#  9309,
#  2279689,
#  683219,
#  2206688,
#  645195,
#  580514,
#  2088954,
#  1103251,
#  1143296,
#  831265,
#  582483,
#  1202412,
#  760041,
#  1409081,
#  1048103,
#  400806,
#  243188,
#  511280,
#  1733030,
#  2198310,
#  733763,
#  602799,
#  1170978,
#  349334,
#  2016008,
#  620476,
#  1464734,
#  1190008,
#  25921,
#  364627,
#  413447,
#  1624851,
#  329976,
#  1784317,
#  1474201,
#  1861096,
#  1710886,
#  1809877,
#  1780743,
#  1054822,
#  1468466,
#  1022192,
#  316655,
#  1874447,
#  1520201,
#  552349,
#  622464,
#  1419813,
#  1325547,
#  423594,
#  2226310,
#  1349145,
#  1285095,
#  1266567,
#  936065,
#  446953,
#  1047008,
#  855443,
#  1863088,
#  1856642,
#  848646,
#  1917878,
#  1635869,
#  2172216,
#  1987994,
#  1278605,
#  107954,
#  1059671,
#  598161,
#  2154648,
#  1371729,
#  255029,
#  740550,
#  1178579,
#  838468,
#  838555,
#  1581644,
#  1636336,
#  2158058,
#  1990855,
#  913539,
#  102303,
#  671821,
#  749391,
#  1353344,
#  1790562,
#  532693,
#  281700,
#  2125527,
#  1604239,
#  1101227,
#  1462914,
#  1173929,
#  2220685,
#  914652,
#  1211217,
#  391697,
#  1569544,
#  1658626,
#  2039316,
#  1344944,
#  893763,
#  1564281,
#  2092057,
#  1280508,
#  1066173,
#  2186705,
#  1975093,
#  2011442,
#  179291,
#  518673,
#  1906989,
#  434187,
#  1022792,
#  1856429,
#  2016652,
#  889766,
#  405455,
#  456888,
#  830188,
#  808168,
#  2250574,
#  2165552,
#  577678,
#  1595712,
#  642739,
#  2170241,
#  1207622,
#  1791152,
#  2289702,
#  764403,
#  2205613,
#  475178,
#  1747754,
#  2114999,
#  1824628,
#  1176453,
#  2130315,
#  1189391,
#  1089384,
#  1490463,
#  2161362,
#  2286694,
#  1562706,
#  1038885,
#  572683,
#  1006797,
#  1119707,
#  1354886,
#  685430,
#  93908,
#  1401695,
#  635769,
#  1116521,
#  1139558,
#  2181982,
#  1194280,
#  2289545,
#  557735,
#  1726676,
#  467961,
#  958383,
#  1606900,
#  2011361,
#  1040376,
#  400774,
#  2027412,
#  562026,
#  112516,
#  110226,
#  1509075,
#  957736,
#  728375,
#  1410474,
#  261592,
#  1811921,
#  103427,
#  464345,
#  2266061,
#  1992045,
#  2215847,
#  1437066,
#  2086145,
#  868082,
#  281460,
#  54128,
#  2021834,
#  1276174,
#  1686955,
#  513158,
#  2076952,
#  506753,
#  1620458,
#  2082490,
#  884555,
#  1618589,
#  1303135,
#  1381916,
#  602901,
#  736686,
#  2240691,
#  1555980,
#  2022473,
#  657389,
#  523320,
#  237154,
#  1225955,
#  1044718,
#  872995,
#  1817692,
#  1499882,
#  1008890,
#  2039368,
#  16136,
#  1548656,
#  1464113,
#  795597,
#  628058,
#  1855256,
#  1182724,
#  264938,
#  619127,
#  1794330,
#  1290536,
#  2181230,
#  1214982,
#  1918121,
#  1611274,
#  1692406,
#  1392153,
#  681980,
#  247629,
#  629437,
#  851682,
#  1593075,
#  1109347,
#  1455094,
#  221702,
#  90831,
#  148428,
#  2075490,
#  494830,
#  2265069,
#  1965145,
#  1608375,
#  1625113,
#  1617565,
#  1022966,
#  1984868,
#  1421181,
#  370655,
#  839586,
#  1518624,
#  918714,
#  482170,
#  1415374,
#  70840,
#  1291714,
#  1847924,
#  1706720,
#  849709,
#  933030,
#  973390,
#  1250214,
#  257942,
#  847922,
#  642583,
#  657370,
#  1139441,
#  1478183,
#  2132811,
#  805192,
#  1861019,
#  1140773,
#  2099797,
#  1419816,
#  509181,
#  1599911,
#  599673,
#  1954377,
#  1808538,
#  121645,
#  913095,
#  1931995,
#  216637,
#  198243,
#  474498,
#  620749,
#  2088720,
#  851536,
#  1390083,
#  1719878,
#  442488,
#  98256,
#  1928124,
#  625807,
#  229946,
#  1634469,
#  1986605,
#  736575,
#  29519,
#  1181082,
#  1631862,
#  1972240,
#  890873,
#  1615714,
#  2199538,
#  617435,
#  122182,
#  1873248,
#  1087458,
#  1248178,
#  1096889,
#  2213558,
#  1887799,
#  29844,
#  1124120,
#  1137166,
#  2070412,
#  1689064,
#  2099293,
#  1309339,
#  2150853,
#  1914826,
#  1152372,
#  1969045,
#  85417,
#  1243107,
#  2187305,
#  1536665,
#  265395,
#  388231,
#  363103,
#  1351506,
#  2052112,
#  1370647,
#  2163488,
#  1888263,
#  621734,
#  495672,
#  1063646,
#  572977,
#  1762941,
#  1580518,
#  1288735,
#  449775,
#  235949,
#  1470541,
#  1418461,
#  1559787,
#  860506,
#  275693,
#  862432,
#  744368,
#  886365,
#  548890,
#  1880946,
#  918356,
#  443602,
#  1930109,
#  1179042,
#  2126614,
#  2214797,
#  863933,
#  79370,
#  1202415,
#  1515872,
#  1343400,
#  1796594,
#  1947238,
#  2012194,
#  263194,
#  1038078,
#  2233811,
#  232147,
#  350112,
#  1278541,
#  1733962,
#  1951718,
#  1634211,
#  236847,
#  1494450,
#  1873363,
#  418413,
#  581156,
#  118148,
#  1239240,
#  612296,
#  2163534,
#  1836318,
#  745122,
#  1307890,
#  325426,
#  1053521,
#  1763265,
#  561025,
#  441598,
#  1068445,
#  446519,
#  1988500,
#  648078,
#  1863933,
#  368706,
#  2065236,
#  1955848,
#  1915195,
#  2280313,
#  2167828,
#  2266321,
#  1311662,
#  1124764,
#  2151124,
#  1046908,
#  1191879,
#  686426,
#  1013919,
#  2060508,
#  1262954,
#  974680,
#  182568,
#  995059,
#  1652050,
#  671577,
#  531383,
#  662885,
#  683029,
#  632970,
#  1079430,
#  2232775,
#  200480,
#  760718,
#  2064223,
#  1898719,
#  595212,
#  710838,
#  936501,
#  1973587,
#  2070562,
#  2008804,
#  1797747,
#  1378400,
#  802810,
#  369497,
#  1170490,
#  413309,
#  1625771,
#  1254646,
#  2044710,
#  157534,
#  1607206,
#  495374,
#  577367,
#  704005,
#  1800303,
#  222423,
#  624689,
#  542905,
#  1268997,
#  1443052,
#  709273,
#  1605628,
#  280014,
#  1328156,
#  2242513,
#  1025704,
#  1865179,
#  1772287,
#  1052135,
#  953791,
#  2216979,
#  475213,
#  926812,
#  1735735,
#  813517,
#  609142,
#  411896,
#  1745921,
#  711238,
#  806884,
#  22341,
#  1677517,
#  848764,
#  36376,
#  2105280,
#  32902,
#  71022,
#  912242,
#  1543917,
#  841921,
#  2261409,
#  1589295,
#  1872250,
#  773645,
#  1124781,
#  794868,
#  115065,
#  1274886,
#  1473901,
#  766876,
#  2199407,
#  874631,
#  61227,
#  1069474,
#  496333,
#  1872889,
#  2061757,
#  1204235,
#  605901,
#  1973252,
#  2069480,
#  62811,
#  269761,
#  873313,
#  859822,
#  1635500,
#  1988150,
#  ...]

# %%
df.loc[target,'App Name'] = pd.NA
df.isna().sum()
# Out:
# App Name            66423
# App Id                  0
# Category                0
# Rating                  0
# Rating Count            0
# Installs                0
# Minimum Installs        0
# Maximum Installs        0
# Free                    0
# Price                   0
# Currency               20
# Size                    0
# Minimum Android      6526
# Released            48378
# Last Updated            0
# Content Rating          0
# Ad Supported            0
# In App Purchases        0
# Editors Choice          0
# Size Approximate        0
# Size Bin            53048
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\kdh\Desktop\projects\project_side_google_app_store\src\4_preprocess_duplicate.ipynb Cell 4' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kdh/Desktop/projects/project_side_google_app_store/src/4_preprocess_duplicate.ipynb#ch0000002?line=3'>4</a> index_lst = []
#       <a href='vscode-notebook-cell:/c%3A/Users/kdh/Desktop/projects/project_side_google_app_store/src/4_preprocess_duplicate.ipynb#ch0000002?line=4'>5</a> for i in app_names:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kdh/Desktop/projects/project_side_google_app_store/src/4_preprocess_duplicate.ipynb#ch0000002?line=5'>6</a>     tmp = target[target['App Name'].str.startswith(i)].sort_values(by=['Rating Count'],ascending=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/kdh/Desktop/projects/project_side_google_app_store/src/4_preprocess_duplicate.ipynb#ch0000002?line=6'>7</a>     the_last = tmp.iloc[1:]
#       <a href='vscode-notebook-cell:/c%3A/Users/kdh/Desktop/projects/project_side_google_app_store/src/4_preprocess_duplicate.ipynb#ch0000002?line=8'>9</a>     indexes = the_last.index.tolist()
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=119'>120</a>     msg = (
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=120'>121</a>         f"Cannot use .str.{func_name} with values of "
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=121'>122</a>         f"inferred dtype '{self._inferred_dtype}'."
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=122'>123</a>     )
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=123'>124</a>     raise TypeError(msg)
# --> <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=124'>125</a> return func(self, *args, **kwargs)
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\core\strings\accessor.py:2285, in StringMethods.startswith(self, pat, na)
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2230'>2231</a> @forbid_nonstring_types(["bytes"])
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2231'>2232</a> def startswith(self, pat, na=None):
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2232'>2233</a>     """
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2233'>2234</a>     Test if the start of each string element matches a pattern.
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2234'>2235</a>
#    (...)
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2282'>2283</a>     dtype: bool
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2283'>2284</a>     """
# -> <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2284'>2285</a>     result = self._data.array._str_startswith(pat, na=na)
#    <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/accessor.py?line=2285'>2286</a>     return self._wrap_result(result, returns_string=False)
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\core\strings\object_array.py:135, in ObjectStringArrayMixin._str_startswith(self, pat, na)
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=132'>133</a> def _str_startswith(self, pat, na=None):
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=133'>134</a>     f = lambda x: x.startswith(pat)
# --> <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=134'>135</a>     return self._str_map(f, na_value=na, dtype=np.dtype(bool))
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\core\strings\object_array.py:71, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=68'>69</a> map_convert = convert and not np.all(mask)
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=69'>70</a> try:
# ---> <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=70'>71</a>     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=71'>72</a> except (TypeError, AttributeError) as err:
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=72'>73</a>     # Reraise the exception if callable `f` got wrong number of args.
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=73'>74</a>     # The user may want to be warned by this, instead of getting NaN
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=74'>75</a>     p_err = (
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=75'>76</a>         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=76'>77</a>         r"(?(3)required )positional arguments?"
#      <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=77'>78</a>     )
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\_libs\lib.pyx:2822, in pandas._libs.lib.map_infer_mask()
#
# File ~\miniconda3\envs\sp\lib\site-packages\pandas\core\strings\object_array.py:134, in ObjectStringArrayMixin._str_startswith.<locals>.<lambda>(x)
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=132'>133</a> def _str_startswith(self, pat, na=None):
# --> <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=133'>134</a>     f = lambda x: x.startswith(pat)
#     <a href='file:///c%3A/Users/kdh/miniconda3/envs/sp/lib/site-packages/pandas/core/strings/object_array.py?line=134'>135</a>     return self._str_map(f, na_value=na, dtype=np.dtype(bool))
#
# KeyboardInterrupt:
