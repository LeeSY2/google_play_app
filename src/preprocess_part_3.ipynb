# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

from lib import get_file_path

# %%
df = pd.read_csv('drop_rating_rating_count.csv')
df
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2290056                                           大俠客—熱血歸來
# 2290057                                         ORU Online
# 2290058                                     Data Structure
# 2290059                                        Devi Suktam
# 2290060                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
df.isna().sum()
# Out:
# App Name                0
# App Id                  0
# Category                0
# Rating                  0
# Rating Count            0
# Installs                0
# Minimum Installs        0
# Maximum Installs        0
# Free                    0
# Price                   0
# Currency               20
# Size                    0
# Minimum Android      6526
# Released            48378
# Last Updated            0
# Content Rating          0
# Ad Supported            0
# In App Purchases        0
# Editors Choice          0
# dtype: int64

# %%
df = df.drop(['Currency', 'Minimum Android'], axis=1)

df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Size',
#        'Released', 'Last Updated', 'Content Rating', 'Ad Supported',
#        'In App Purchases', 'Editors Choice'],
#       dtype='object')

# %%
df1 = df.dropna(subset=['Released'])

# %%
df1.isna().sum()
# Out:
# App Name            0
# App Id              0
# Category            0
# Rating              0
# Rating Count        0
# Installs            0
# Minimum Installs    0
# Maximum Installs    0
# Free                0
# Price               0
# Size                0
# Released            0
# Last Updated        0
# Content Rating      0
# Ad Supported        0
# In App Purchases    0
# Editors Choice      0
# dtype: int64

# %%
df1
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2290055                        Lero TOEFL Recorder + Timer
# 2290057                                         ORU Online
# 2290058                                     Data Structure
# 2290059                                        Devi Suktam
# 2290060                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
print(df1['Size'].unique().tolist())
# Out:
# ['10M', '2.9M', '3.7M', '1.8M', '6.2M', '46M', '2.5M', '16M', '3.5M', '51M', '2.7M', '7.6M', '15M', '29M', '12M', '2.0M', '70M', '11M', '24M', '1.4M', '20M', '2.4M', '25M', '21M', '36M', '6.1M', '2.6M', '8.9M', '3.9M', '30M', '26M', '4.9M', '4.3M', '4.8M', '4.6M', '2.8M', '38M', '5.1M', '147M', '33M', '2.2M', '7.1M', '27M', '18M', '32M', '19M', '39M', '31M', '1.2M', '3.1M', '3.2M', '42M', '22M', '4.1M', '50M', '5.5M', '127k', '8.4M', '41M', '49M', '1.3M', '7.0M', '4.7M', '7.7M', '43M', '5.4M', '3.0M', '1.6M', '2.1M', '37M', '3.6M', '9.0M', '9.9M', '67M', '28M', '7.9M', '3.3M', '6.0M', '5.7M', '9.8M', '5.0M', '1.7M', '7.4M', '1.9M', 'Varies with device', '3.8M', '6.4M', '8.1M', '6.5M', '4.4M', '45M', '7.2M', '13M', '6.9M', '60M', '6.6M', '4.0M', '17M', '4.2M', '58M', '93M', '9.7M', '23M', '52M', '5.6M', '48M', '1.5M', '8.5M', '54M', '62M', '133M', '64M', '152M', '9.5M', '4.5M', '40M', '531k', '8.0M', '2.3M', '35M', '83M', '7.3M', '6.7M', '9.4M', '69M', '7.5M', '343k', '84M', '5.9M', '
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290061 entries, 0 to 2290060
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   App Name          object
#  1   App Id            object
#  2   Category          object
#  3   Rating            float64
#  4   Rating Count      float64
#  5   Installs          object
#  6   Minimum Installs  float64
#  7   Maximum Installs  int64
#  8   Free              bool
#  9   Price             float64
#  10  Size              object
#  11  Released          object
#  12  Last Updated      object
#  13  Content Rating    object
#  14  Ad Supported      bool
#  15  In App Purchases  bool
#  16  Editors Choice    bool
# dtypes: bool(4), float64(4), int64(1), object(8)
# memory usage: 235.9+ MB

# %%
data_info = pd.DataFrame()
data_info['Column Names'] = df1.columns
data_info['Datatype'] = df1.dtypes.to_list()
data_info['Duplicate'] = data_info['Column Names'].apply(lambda x: df1[x].duplicated().sum())
data_info
# Out:
#         Column Names Datatype  Duplicate
# 0           App Name   object     131144
# 1             App Id   object          0
# 2           Category   object    2241635
# 3             Rating  float64    2241641
# 4       Rating Count  float64    2204099
# 5           Installs   object    2241661
# 6   Minimum Installs  float64    2241661
# 7   Maximum Installs    int64    1995406
# 8               Free     bool    2241681
# 9              Price  float64    2240802
# 10              Size   object    2240033
# 11          Released   object    2237525
# 12      Last Updated   object    2237801
# 13    Content Rating   object    2241677
# 14      Ad Supported     bool    2241681
# 15  In App Purchases     bool    2241681
# 16    Editors Choice     bool    2241681

# %%
df1
# Out:
#                                                   App Name  \
# 0                                                  Gakondo
# 1                                      Ampere Battery Info
# 2                                                   Vibook
# 3        Smart City Trichy Public Service Vehicles 17UC...
# 4                                                  GROW.me
# ...                                                    ...
# 2290055                        Lero TOEFL Recorder + Timer
# 2290057                                         ORU Online
# 2290058                                     Data Structure
# 2290059                                        Devi Suktam
# 2290060                       Biliyor Musun - Sonsuz Yarış
#
#                                        App Id       Category  Rating  \
# 0                         com.ishakwe.gakondo      Adventure     0.0
# 1                  com.webserveis.batteryinfo          Tools     4.4
# ...

# %%
df2 = df1[df1.duplicated(subset=['App Name'], keep=False)].sort_values(by=['App Name'])

# %%
df3 = df2[['App Name', 'Rating Count']]

df3
# Out:
#                                                   App Name  Rating Count
# 808578                                          #AKTIVIZIM           0.0
# 1737470                                         #AKTIVIZIM          26.0
# 1537546                                            #imOKru           0.0
# 676853                                             #imOKru           6.0
# 1797053                                              #team           0.0
# ...                                                    ...           ...
# 1057707                         👒 👓 College Girls Dress Up        1897.0
# 642300   💎Stickers de Mikecrack y Los Compas para WhatsApp       18744.0
# 214338   💎Stickers de Mikecrack y Los Compas para WhatsApp         179.0
# 630728                                    🥠 Fortune Cookie          61.0
# 1633038                                   🥠 Fortune Cookie          28.0
#
# [196435 rows x 2 columns]

# %%
name_lst = df3['App Name'].unique().tolist()
name_lst
# Out:
# ['#AKTIVIZIM',
#  '#imOKru',
#  '#team',
#  '(G)I-DLE Wallpaper',
#  '.Chase',
#  '.Net Interview Questions',
#  '1 Minute Me Aadhar Loan - आधार कार्ड पे लोन गाइड',
#  '1 Minute Me Aadhar Loan Guide - आधार कार्ड पे लोन',
#  '1 Oldies',
#  '1 Pic 1 Word',
#  '1 Volt',
#  '1+1=2',
#  '10 Best Foods for You',
#  '10 Minutes',
#  '10 Seconds',
#  '10 Years Challenge',
#  '10,000 Chistes',
#  '100',
#  '100 Balls',
#  '100 Balls Drop',
#  '100 Doors Journey',
#  '100 GB Free Data Internet: Free MB 3G 4G (Prank)',
#  '100 Keyboard Shortcuts',
#  '100 PICS Quiz - Guess Trivia, Logo & Picture Games',
#  '100 Plus Academy',
#  '100 Questions',
#  '100 Spørsmål',
#  '100 Weight Loss Tips',
#  '100% Noticias',
#  '100% Sure Correct Score',
#  '100+ CEILING DESIGN',
#  '100+ Famous Places India',
#  '1000 Books Before Kindergarten',
#  '1000 Christmas',
#  '1000 English Stories',
#  '1000 English Stories (Offline)',
#  '1000 Powerful Affirmations',
#  '1000 words',
#  '1000+ English Stories',
# ...

# %%
df3.loc[df3['App Name'].str.match('#AKTIVIZIM')].sort_values(by=['Rating Count'],ascending=False)
# Out:
#            App Name  Rating Count
# 1737470  #AKTIVIZIM          26.0
# 808578   #AKTIVIZIM           0.0
